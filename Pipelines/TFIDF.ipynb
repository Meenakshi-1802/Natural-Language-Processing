# %% [markdown]
# # TF-IDF -
#
# ## Overview
# TF-IDF (Term Frequency-Inverse Document Frequency) assigns importance to words based on:
# - How often they appear in a document
# - How rare they are across all documents

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

corpus = ["I love NLP", "NLP is fun"]
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)

print(vectorizer.get_feature_names_out())
print(X.toarray())
# Out:
# ['fun' 'is' 'love' 'nlp']
# [[0.         0.         0.81480247 0.57973867]
#  [0.6316672  0.6316672  0.         0.44943642]]
